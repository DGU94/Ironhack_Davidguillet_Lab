# %% [markdown]
# * [Describing holiday of my camarade](#first-bullet)
# * [Second Bullet Header](#second-bullet)

# %% [markdown]
# **Describing holiday of my camarade**

# %%
a = input("Enter your name: ")
# Out:
# Enter your name:

# %%
from IPython import display
display.Image("https://media.wired.com/photos/598e35fb99d76447c4eb1f28/16:9/w_2123,h_1194,c_limit/phonepicutres-TA.jpg")

# %%
display.Image("https://www.ski-nordique.net/getfile.php/4914128.1046.wkqqtasiqzalil/ASPEN.jpg")

# %% [markdown]
# The top 3 things that the person likes to do at this destination are :
# - <font color=blue>waking up early to see the sunrise</font>
# - __breakfast on the balcony__
# - _riding the mountain until the nightfall_

# %% [markdown]
# * Describing holiday of my camarade

# %% [markdown]
# Here you can find a video of this awesome experience :

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('https://www.youtube.com/watch?v=KR-87fZIxkg')
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/https://www.youtube.com/watch?v=KR-87fZIxkg"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
